# %%
from PIL import Image

# %%
im1 = Image.open("./Images/brownfields_cnt.png")
im2 = Image.open("./Images/low_income_rate.png")
# 指定目標圖片大小
imgSize = (960, 480)

# 改變影像大小
im1 = im1.resize(imgSize)
im2 = im2.resize(imgSize)

# %%
im1
# Out:
# <PIL.Image.Image image mode=RGBA size=960x480 at 0x23A85ADF880>

# %%
im2
# Out:
# <PIL.Image.Image image mode=RGBA size=960x480 at 0x23A85ADF190>

# %%
blended = Image.blend(im1, im2, alpha=0.5)

# %%
blended
# Out:
# <PIL.Image.Image image mode=RGBA size=960x480 at 0x23A85553310>
